# %%
import pandas as pd

# %%
pd.read_html('http://www.ufcstats.com/event-details/31652c9267606d54')[0]
# Out:
#           W/L                       Fighter     Str    Td   Sub  Pass  \
# 0         win       Pedro Rizzo  Dan Severn    2  0  0  0  0  0  0  0
# 1         win  Maurice Smith  Bobby Hoffman  43  10  0  4  0  0  0  3
# 2         win   Jeremy Horn  Eugene Jackson    2  2  1  0  1  0  3  0
# 3         win    Fabiano Iha  Laverne Clark    1  1  1  0  2  0  0  0
# 4         win  Yuki Kondo  Alexandre Dantas  33  14  0  2  0  0  1  4
# 5         win    Ian Freeman  Tedd Williams  30  25  0  1  0  0  0  1
# 6         win       Jeff Monson  Tim Lajcik   31  5  1  0  0  0  2  0
# 7  draw  draw       Brad Gumm  CJ Fernandes  18  28  0  1  0  0  1  0
#
#    Weight class               Method  Round  Time
# 0   Heavyweight        KO/TKO  Kicks      1  1:33
# 1   Heavyweight                S-DEC      3  5:00
# 2  Middleweight          SUB  Armbar      1  4:32
# 3  Welterweight          SUB  Armbar      1  1:10
# 4  Middleweight  KO/TKO  Flying Knee      3  2:28
# ...

# %%
pd.read_html('http://www.ufcstats.com/statistics/fighters?char=a&page=all')[0]
# Out:
#        First          Last      Nickname     Ht.       Wt.  Reach    Stance  \
# 0        NaN           NaN           NaN     NaN       NaN    NaN       NaN
# 1        Tom         Aaron           NaN      --  155 lbs.     --       NaN
# 2      Danny        Abbadi  The Assassin  5' 11"  155 lbs.     --  Orthodox
# 3      David        Abbott          Tank   6' 0"  265 lbs.     --    Switch
# 4     Shamil  Abdurakhimov         Abrek   6' 3"  235 lbs.  76.0"  Orthodox
# ..       ...           ...           ...     ...       ...    ...       ...
# 161      Abu       Azaitar           NaN   5' 9"  185 lbs.  76.0"  Orthodox
# 162   Ottman       Azaitar     Bulldozer   5' 8"  155 lbs.  71.0"    Switch
# 163     Luiz       Azeredo           NaN   5' 9"  154 lbs.     --  Orthodox
# 164  Luciano       Azevedo           NaN   6' 3"  161 lbs.     --  Orthodox
# 165   Hunter         Azure           NaN   5' 8"  145 lbs.  69.0"  Orthodox
#
#         W     L    D  Belt
# 0     NaN   NaN  NaN   NaN
# ...
