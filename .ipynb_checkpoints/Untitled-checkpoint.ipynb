# %%
import pandas as pd

# %%
test = pd.read_html('http://www.ufcstats.com/event-details/620be7e0712d431b')[0]

# %%
test
# Out:
#     W/L                             Fighter       Str    Td   Sub  Pass  \
# 0   win      Dustin Poirier  Justin Gaethje  174  115  0  0  0  0  0  0
# 1   win        Alex Oliveira  Carlos Condit     9  12  3  1  1  1  4  2
# 2   win     Israel Adesanya  Marvin Vettori    57  46  0  2  0  0  0  1
# 3   win    Michelle Waterson  Cortney Casey    61  36  3  0  0  3  0  1
# 4   win  Antonio Carlos Junior  Tim Boetsch     31  7  1  0  1  0  1  0
# 5   win       Muslim Salikhov  Ricky Rainey    25  19  0  0  0  0  0  0
# 6   win            John Moraga  Wilson Reis    46  12  0  8  1  0  1  8
# 7   win       Brad Tavares  Krzysztof Jotko    46  24  0  0  0  0  0  0
# 8   win            Gilbert Burns  Dan Moret    31  20  2  0  0  0  2  0
# 9   win        Lauren Mueller  Shana Dobson    58  68  2  1  0  0  1  0
# 10  win           Yushin Okami  Dhiego Lima    15  11  6  0  0  0  6  0
# 11  win       Adam Wieczorek  Arjan Bhullar     13  9  0  2  1  0  0  1
# ...

# %%
holder = pd.read_html('http://www.ufcstats.com/statistics/fighters?char=a&page=all')

# %%
holder
# Out:
# [       First          Last      Nickname     Ht.       Wt.  Reach    Stance  \
#  0        NaN           NaN           NaN     NaN       NaN    NaN       NaN
#  1        Tom         Aaron           NaN      --  155 lbs.     --       NaN
#  2      Danny        Abbadi  The Assassin  5' 11"  155 lbs.     --  Orthodox
#  3      David        Abbott          Tank   6' 0"  265 lbs.     --    Switch
#  4     Shamil  Abdurakhimov         Abrek   6' 3"  235 lbs.  76.0"  Orthodox
#  ..       ...           ...           ...     ...       ...    ...       ...
#  161      Abu       Azaitar           NaN   5' 9"  185 lbs.  76.0"  Orthodox
#  162   Ottman       Azaitar     Bulldozer   5' 8"  155 lbs.  71.0"    Switch
#  163     Luiz       Azeredo           NaN   5' 9"  154 lbs.     --  Orthodox
#  164  Luciano       Azevedo           NaN   6' 3"  161 lbs.     --  Orthodox
#  165   Hunter         Azure           NaN   5' 8"  145 lbs.  69.0"  Orthodox
#
#          W     L    D  Belt
# ...

# %%
holder[2]
# Out:
# '42 of 90  28 of 72'

# %%
test = pd.read_html('http://www.ufcstats.com/fight-details/73c70a628f0ef14b')

# %%
for x in range(0, len(test)):
    display(test[x])
# Out:
#                         Fighter    KD           Sig. str. Sig. str. %  \
# 0  Carla Esparza Rose Namajunas  0  0  42 of 90  28 of 72    46%  38%
#
#              Total str.              Td      Td % Sub. att  Pass  Rev.
# 0  107 of 180  29 of 73  5 of 7  1 of 3  71%  33%     1  0  6  0  0  0
#                         Fighter      KD           Sig. str. Sig. str. %  \
#                         Round 1 Round 1             Round 1     Round 1
#                         Round 2 Round 2             Round 2     Round 2
#                         Round 3 Round 3             Round 3     Round 3
# 0  Carla Esparza Rose Namajunas    0  0  19 of 54  18 of 47    35%  38%
# 1  Carla Esparza Rose Namajunas    0  0   19 of 31  9 of 23    61%  39%
# 2  Carla Esparza Rose Namajunas    0  0      4 of 5  1 of 2    80%  50%
#
#            Total str.            Td %           Sub. att    Pass    Rev.
#               Round 1         Round 1            Round 1 Round 1 Round 1
# ...

# %%
holder = test.iloc[0]

# %%
fighter_list = holder.Fighter.split()

# %%
name1 = fighter_list[:2]
name1
separator = ' '

# %%
print(separator.join(name1))
# Out:
# Carla Esparza
